# %%
# Needed for SQL Alchemy  
from sqlalchemy import create_engine

# All query results are returned as Pandas DataFrames 
import pandas as pd

# Needed for %sql Magic
# %load_ext sql

# %%
# Connect to the deals database
# %sql mysql+pymysql://root:mysql@localhost/deals
# Out:
# /Users/trangvu/anaconda3/lib/python3.6/site-packages/pymysql/cursors.py:166: Warning: (1287, "'@@tx_isolation' is deprecated and will be removed in a future release. Please use '@@transaction_isolation' instead")
#   result = self._query(query)
# 'Connected: root@deals'

# %%
# Create a view that matches companies to deals
result = %sql SELECT * FROM CompanyDeals;
companies = result.DataFrame()
companies
# Out:
# 332 rows affected.
#                                           DealName RoleCode  \
# 0                                      ADT Limited       B1
# 1                                      ADT Limited       B2
# 2                                      ADT Limited        T
# 3                                    Advanta Corp.        A
# 4                                    Advanta Corp.        T
# 5                                 Alex. Brown Inc.        A
# 6                                 Alex. Brown Inc.        T
# 7                        Allied Colloids Group PLC        T
# 8                        Allied Colloids Group PLC       B1
# 9    American First Financial Insurance Group Inc.        T
# 10   American First Financial Insurance Group Inc.        A
# 11                 American Medical Response, Inc.        A
# 12                 American Medical Response, Inc.        T
# 13                    American Radio Systems Corp.        A
# ...

# %%
# Create a view named DealValues that lists the DealID, total dollar value and number of parts for each deal.
result = %sql SELECT * FROM DealValues;
companies = result.DataFrame()
companies
# Out:
# 151 rows affected.
#      DealID TotDollarValue  NumParts
# 0         1      5600.0000         1
# 1         2      1700.0000         1
# 2         3      1120.0000         1
# 3         4      4000.0000         1
# 4         5      1500.0000         1
# 5         6      1600.0000         1
# 6         7      1870.0000         1
# 7         8      3700.0000         1
# 8         9      1600.0000         1
# 9        10      1200.0000         1
# 10       11      1617.0000         1
# 11       12      1360.0000         1
# 12       13      1270.0000         1
# 13       14      4210.0000         1
# 14       15      1150.0000         1
# 15       16      9700.0000         1
# 16       17      1050.0000         1
# 17       18      7000.0000         1
# 18       19      3400.0000         1
# 19       20      9500.0000         1
# 20       21      6590.0000         1
# 21       22      1700.0000         1
# 22       23      1100.0000         1
# 23       24      1355.0000         1
# ...

# %%
# Create a view named DealSummary that lists the DealID, DealName, number of players, total dollar value, and number of parts for each deal.
result = %sql SELECT * FROM DealSummary;
companies = result.DataFrame()
companies
# Out:
# 149 rows affected.
#      DealID                                           DealName  NumPlayers  \
# 0         1                                        ADT Limited           3
# 1         2                                   Alex. Brown Inc.           2
# 2         3                    American Medical Response, Inc.           2
# 3         4                  American Standard Companies, Inc.           2
# 4         5                                     Amphenol Corp.           2
# 5         6                                  Bankamerica Corp.           1
# 6         7                          Berliner Kraft & Licht AG           1
# 7         8                       Cascade Communications Corp.           2
# 8         9                      Chancellor Broadcasting Comp.           2
# 9        10                                         Cifra S.A.           2
# 10       11  Coca Cola Bottling Co. of New York and Coca-Co...           2
# ...

# %%
#Create a view called DealsByType that lists TypeCode, number of deals, and total value of deals for each deal type.
result = %sql SELECT * FROM DealsByType;
companies = result.DataFrame()
companies
# Out:
# 6 rows affected.
#   TypeCode  NumDeals TotDollaValue
# 0      C/S        80   271794.0000
# 1       CM         3     8030.0000
# 2       PA         1     1880.0000
# 3       PF         4    27790.0000
# 4       SS        59   204658.0000
# 5       TO        16    55972.0000

# %%
# Create a view called DealPlayers that lists the CompanyID, Name, and Role Code for each deal. Sort the players by the RoleSortOrder.
result = %sql SELECT * FROM DealPlayers;
companies = result.DataFrame()
companies
# Out:
# 332 rows affected.
#      DealID  CompanyID                                        CompanyName  \
# 0       133        277                              Allied Colloids Group
# 1         1          3                                        ADT Limited
# 2         2          6                                   Alex. Brown Inc.
# 3         3         11                    American Medical Response, Inc.
# 4         4         13                  American Standard Companies, Inc.
# 5         5         16                                     Amphenol Corp.
# 6         6        216                Security Pacific Financial Services
# 7         8         39                       Cascade Communications Corp.
# 8         9         43                      Chancellor Broadcasting Comp.
# 9        10         46                                         Cifra S.A.
# 10       11         51  Coca Cola Bottling Co. of New York and Coca-Co...
# ...

# %%
# Create a view called DealsByFirm that lists the FirmID, Name, number of deals, and total value of deals for each firm.
result = %sql SELECT * FROM DealsByFirm;
companies = result.DataFrame()
companies
# Out:
# 257 rows affected.
#      FirmID                                             Name  NumDeals  \
# 0         2                                       Bryan Cave         4
# 1         3                                Buchanan Ingersol         1
# 2        11                           Dechert Price & Rhoads         2
# 3        12                              Davies, Ward & Beck         1
# 4        19                             Fulbright & Jaworski         4
# 5        33                                Swindler & Berlin         2
# 6        36                                 Troutman Sanders         1
# 7        41                                Goulston & Storrs         1
# 8        42                      Goodman Phillips & Vineberg         1
# 9        46      Robinson Silverman Pearce Aronsohn & Berman         1
# 10       50                                   Schreck Morris         1
# 11       62                            Hughes Hubbard & Reed         1
# ...
